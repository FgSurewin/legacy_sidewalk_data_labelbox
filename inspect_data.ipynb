# %%
# %pip install moviepy
# Out:
# Requirement already satisfied: moviepy in /Users/JL/opt/anaconda3/envs/labelbox/lib/python3.10/site-packages (2.2.1)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/JL/opt/anaconda3/envs/labelbox/lib/python3.10/site-packages (from moviepy) (5.2.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/JL/opt/anaconda3/envs/labelbox/lib/python3.10/site-packages (from moviepy) (2.37.0)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /Users/JL/opt/anaconda3/envs/labelbox/lib/python3.10/site-packages (from moviepy) (0.6.0)
# Requirement already satisfied: numpy>=1.25.0 in /Users/JL/opt/anaconda3/envs/labelbox/lib/python3.10/site-packages (from moviepy) (2.2.6)
# Requirement already satisfied: proglog<=1.0.0 in /Users/JL/opt/anaconda3/envs/labelbox/lib/python3.10/site-packages (from moviepy) (0.1.12)
# Requirement already satisfied: python-dotenv>=0.10 in /Users/JL/opt/anaconda3/envs/labelbox/lib/python3.10/site-packages (from moviepy) (1.1.1)
# Requirement already satisfied: pillow<12.0,>=9.2.0 in /Users/JL/opt/anaconda3/envs/labelbox/lib/python3.10/site-packages (from moviepy) (11.3.0)
# Requirement already satisfied: tqdm in /Users/JL/opt/anaconda3/envs/labelbox/lib/python3.10/site-packages (from proglog<=1.0.0->moviepy) (4.67.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from glob import glob
import pandas as pd
import os
from pathlib import Path
# from moviepy.editor import VideoFileClip

# %%
# Define the root directory where we'll search for videos
root_dir = Path('10_3_2023_all_data')

def clean_material_name(material):
    """Clean and standardize material names"""
    # Convert to lowercase first
    material = material.lower()
    
    # Standard replacements
    replacements = {
        'none': 'none',
        'subway+grate': 'subway_grate',
        'cellar+door': 'cellar_door',
        'concrete+tactile': 'concrete_tactile',
        'concret+tactile': 'concrete_tactile',
        'concrete+stones': 'concrete_stones',
        'storm drains': 'storm_drain',
        'floor art': 'floor_art'
    }
    
    # Replace + with _ and clean up spaces
    material = material.replace('+', '_').strip()
    
    # Apply standard replacements
    return replacements.get(material, material)

# Find all .MOV files recursively
video_files = []
for video_path in root_dir.rglob('*.MOV'):
    # Get the collector name (parent folder name)
    collector_name = video_path.parent.name
    
    # Extract material from filename
    filename = video_path.stem  # removes .MOV extension
    material = filename.split('_')[-1]  # get last part after underscore
    
    # Store information in a dictionary
    video_info = {
        'video_name': video_path.name,
        'collector_name': collector_name,
        'material': clean_material_name(material),
        'full_path': str(video_path)
    }
    video_files.append(video_info)

# Create a DataFrame
df = pd.DataFrame(video_files)

# Save to CSV
output_file = 'video_inventory.csv'
df.to_csv(output_file, index=False)
print(f"Found {len(video_files)} video files")
print(f"Data saved to {output_file}")
df.head()
# Out:
# Found 1525 video files
# Data saved to video_inventory.csv
#                             video_name collector_name material  \
# 0  6_2023-06-30_11-15-18-5960_None.MOV          wayne     none
# 1  1_2023-06-30_11-07-11-9360_None.MOV          wayne     none
# 2  1_2023-06-16_11_59_12.9130_None.MOV          wayne     none
# 3  3_2023-06-16_11_42_44.9410_None.MOV          wayne     none
# 4  1_2023-06-30_10-58-42-3550_None.MOV          wayne     none
#
#                                            full_path
# 0  10_3_2023_all_data/testbed/old_testbed/user_da...
# 1  10_3_2023_all_data/testbed/old_testbed/user_da...
# 2  10_3_2023_all_data/testbed/old_testbed/user_da...
# 3  10_3_2023_all_data/testbed/old_testbed/user_da...
# 4  10_3_2023_all_data/testbed/old_testbed/user_da...

# %%
# Show unique materials and their counts
material_counts = df['material'].value_counts()
print("Unique materials and their counts after cleaning:")
print(material_counts)
# Out:
# Unique materials and their counts after cleaning:
# material
# none                755
# concrete            103
# manhole              92
# subway_grate         87
# dirt                 83
# brick                73
# cellar_door          71
# tactile              70
# metal                61
# asphalt              43
# grass                33
# grate                12
# storm_drain          11
# granite               6
# carpet                5
# concrete_tactile      5
# concrete_stones       4
# stone                 4
# concret_tactile       4
# floor_art             3
# Name: count, dtype: int64

# %%
# Install opencv-python if not already installed
# %pip install opencv-python

import cv2

# Function to get video duration
def get_video_duration(video_path):
    try:
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            return None
        fps = cap.get(cv2.CAP_PROP_FPS)
        frame_count = cap.get(cv2.CAP_PROP_FRAME_COUNT)
        duration = frame_count / fps
        cap.release()
        return round(duration, 2)
    except Exception as e:
        print(f"Error reading {video_path}: {str(e)}")
        return None

# Add durations to our dataframe
print("Calculating video durations...")
df['duration'] = df['full_path'].apply(get_video_duration)

# Save updated CSV
df.to_csv(output_file, index=False)

# Show summary statistics of video durations
print("\nVideo duration statistics (in seconds):")
print(df['duration'].describe())

# Show a few example rows
print("\nExample rows with durations:")
print(df[['video_name', 'collector_name', 'material', 'duration']].head())
# Out:
# Calculating video durations...
#
# Video duration statistics (in seconds):
# count    1525.000000
# mean       34.571351
# std        19.344797
# min         0.200000
# 25%        20.100000
# 50%        32.350000
# 75%        42.270000
# max       185.160000
# Name: duration, dtype: float64
#
# Example rows with durations:
#                             video_name collector_name material  duration
# 0  6_2023-06-30_11-15-18-5960_None.MOV          wayne     none     59.79
# 1  1_2023-06-30_11-07-11-9360_None.MOV          wayne     none     59.79
# 2  1_2023-06-16_11_59_12.9130_None.MOV          wayne     none     59.79
# 3  3_2023-06-16_11_42_44.9410_None.MOV          wayne     none     55.33
# 4  1_2023-06-30_10-58-42-3550_None.MOV          wayne     none     59.76
#
# Video duration statistics (in seconds):
# count    1525.000000
# mean       34.571351
# std        19.344797
# min         0.200000
# 25%        20.100000
# 50%        32.350000
# 75%        42.270000
# max       185.160000
# Name: duration, dtype: float64
#
# Example rows with durations:
#                             video_name collector_name material  duration
# 0  6_2023-06-30_11-15-18-5960_None.MOV          wayne     none     59.79
# 1  1_2023-06-30_11-07-11-9360_None.MOV          wayne     none     59.79
# 2  1_2023-06-16_11_59_12.9130_None.MOV          wayne     none     59.79
# 3  3_2023-06-16_11_42_44.9410_None.MOV          wayne     none     55.33
# 4  1_2023-06-30_10-58-42-3550_None.MOV          wayne     none     59.76

# %%
df.head()
# Out:
#                             video_name collector_name material  \
# 0  6_2023-06-30_11-15-18-5960_None.MOV          wayne     none
# 1  1_2023-06-30_11-07-11-9360_None.MOV          wayne     none
# 2  1_2023-06-16_11_59_12.9130_None.MOV          wayne     none
# 3  3_2023-06-16_11_42_44.9410_None.MOV          wayne     none
# 4  1_2023-06-30_10-58-42-3550_None.MOV          wayne     none
#
#                                            full_path  duration
# 0  10_3_2023_all_data/testbed/old_testbed/user_da...     59.79
# 1  10_3_2023_all_data/testbed/old_testbed/user_da...     59.79
# 2  10_3_2023_all_data/testbed/old_testbed/user_da...     59.79
# 3  10_3_2023_all_data/testbed/old_testbed/user_da...     55.33
# 4  10_3_2023_all_data/testbed/old_testbed/user_da...     59.76

# %%
df.to_csv(output_file, index=False)

# %%
# Separate videos into continuous (none material) and static (with material)
continuous_videos = df[df['material'] == 'none'].copy()
static_videos = df[df['material'] != 'none'].copy()

print(f"Number of continuous videos (no material): {len(continuous_videos)}")
print(f"Number of static videos (with material): {len(static_videos)}")

# Save both dataframes to separate CSV files
continuous_videos.to_csv('continuous_videos.csv', index=False)
static_videos.to_csv('static_videos.csv', index=False)

# Show sample from each dataframe
print("\nSample of continuous videos:")
print(continuous_videos[['video_name', 'collector_name', 'material', 'duration']].head())

print("\nSample of static videos:")
print(static_videos[['video_name', 'collector_name', 'material', 'duration']].head())

# Show material distribution in static videos
print("\nMaterial distribution in static videos:")
print(static_videos['material'].value_counts())
# Out:
# Number of continuous videos (no material): 755
# Number of static videos (with material): 770
#
# Sample of continuous videos:
#                             video_name collector_name material  duration
# 0  6_2023-06-30_11-15-18-5960_None.MOV          wayne     none     59.79
# 1  1_2023-06-30_11-07-11-9360_None.MOV          wayne     none     59.79
# 2  1_2023-06-16_11_59_12.9130_None.MOV          wayne     none     59.79
# 3  3_2023-06-16_11_42_44.9410_None.MOV          wayne     none     55.33
# 4  1_2023-06-30_10-58-42-3550_None.MOV          wayne     none     59.76
#
# Sample of static videos:
#                                       video_name  collector_name  \
# 122  0_2023-08-21 13_31_45.3030_Subway+grate.MOV  jiawei_testbed
# 123       0_2023-08-21 13_25_10.3210_Manhole.MOV  jiawei_testbed
# 125  1_2023-08-21 13_31_45.3030_Subway+grate.MOV  jiawei_testbed
# 126   0_2023-08-21 13_35_23.4820_Cellar+door.MOV  jiawei_testbed
# 128       0_2023-08-21 13_24_23.9400_Manhole.MOV  jiawei_testbed
#
#          material  duration
# 122  subway_grate     59.85
# 123       manhole      5.60
# 125  subway_grate      3.20
# 126   cellar_door      9.37
# 128       manhole      7.40
#
# Material distribution in static videos:
# material
# concrete            103
# manhole              92
# subway_grate         87
# dirt                 83
# brick                73
# cellar_door          71
# tactile              70
# metal                61
# asphalt              43
# grass                33
# grate                12
# storm_drain          11
# granite               6
# carpet                5
# concrete_tactile      5
# concrete_stones       4
# stone                 4
# concret_tactile       4
# floor_art             3
# Name: count, dtype: int64

# %%
# Check for duplicates in continuous_videos
duplicate_mask = continuous_videos.duplicated(subset=['video_name'], keep=False)
duplicated_videos = continuous_videos[duplicate_mask].sort_values('video_name')

print("Number of duplicated videos found:", len(duplicated_videos) // 2)
print("\nExample of duplicated videos:")
print(duplicated_videos[['video_name', 'collector_name', 'full_path']].head(10))

# Create a clean version without duplicates (keeping the first occurrence)
continuous_videos_clean = continuous_videos.drop_duplicates(subset=['video_name'], keep='first').copy()

print("\nOriginal continuous videos count:", len(continuous_videos))
print("Clean continuous videos count:", len(continuous_videos_clean))

# Save the clean version to a new CSV
continuous_videos_clean.to_csv('continuous_videos_clean.csv', index=False)

# Show distribution of collectors in original vs clean dataset
print("\nCollector distribution in original dataset:")
print(continuous_videos['collector_name'].value_counts())

print("\nCollector distribution in clean dataset:")
print(continuous_videos_clean['collector_name'].value_counts())
# Out:
# Number of duplicated videos found: 24
#
# Example of duplicated videos:
#                               video_name collector_name  \
# 4    1_2023-06-30_10-58-42-3550_None.MOV          wayne
# 267  1_2023-06-30_10-58-42-3550_None.MOV          nihal
# 266  1_2023-06-30_11-07-11-9360_None.MOV          nihal
# 1    1_2023-06-30_11-07-11-9360_None.MOV          wayne
# 280  1_2023-06-30_11-15-18-5960_None.MOV          nihal
# 34   1_2023-06-30_11-15-18-5960_None.MOV          wayne
# 287  1_2023-06-30_11-23-29-2950_None.MOV          nihal
# 43   1_2023-06-30_11-23-29-2950_None.MOV          wayne
# 272  2_2023-06-30_10-58-42-3550_None.MOV          nihal
# 20   2_2023-06-30_10-58-42-3550_None.MOV          wayne
#
#                                              full_path
# 4    10_3_2023_all_data/testbed/old_testbed/user_da...
# 267  10_3_2023_all_data/testbed/user_data/nihal/1_2...
# 266  10_3_2023_all_data/testbed/user_data/nihal/1_2...
# 1    10_3_2023_all_data/testbed/old_testbed/user_da...
# 280  10_3_2023_all_data/testbed/user_data/nihal/1_2...
# 34   10_3_2023_all_data/testbed/old_testbed/user_da...
# 287  10_3_2023_all_data/testbed/user_data/nihal/1_2...
# 43   10_3_2023_all_data/testbed/old_testbed/user_da...
# 272  10_3_2023_all_data/testbed/user_data/nihal/2_2...
# 20   10_3_2023_all_data/testbed/old_testbed/user_da...
#
# Original continuous videos count: 755
# Clean continuous videos count: 731
#
# Collector distribution in original dataset:
# collector_name
# junha.kim                         207
# wayne.lam001@stu.bmcc.cuny.edu    200
# prof_tang                          72
# wayne_testbed                      60
# victor_testbed                     49
# wayne                              45
# junha_testbed                      42
# nihal                              24
# junha_8_18                         17
# wayne_8_18                         12
# jiawei_testbed                      7
# jun_ha                              5
# jiawei-walk-test                    4
# Daeshawn LaBrew                     4
# Dilshod Ochilov                     3
# Christian Barbosa                   2
# Nabeel Ahmed                        1
# Dilshodpart3                        1
# Name: count, dtype: int64
#
# Collector distribution in clean dataset:
# collector_name
# junha.kim                         207
# wayne.lam001@stu.bmcc.cuny.edu    200
# prof_tang                          72
# wayne_testbed                      60
# victor_testbed                     49
# wayne                              45
# junha_testbed                      42
# junha_8_18                         17
# wayne_8_18                         12
# jiawei_testbed                      7
# jun_ha                              5
# jiawei-walk-test                    4
# Daeshawn LaBrew                     4
# Dilshod Ochilov                     3
# Christian Barbosa                   2
# Nabeel Ahmed                        1
# Dilshodpart3                        1
# Name: count, dtype: int64

# %%
# Group duplicates by video name to see where they appear
duplicate_analysis = duplicated_videos.groupby('video_name').agg({
    'collector_name': lambda x: list(x),
    'full_path': lambda x: list(x)
}).reset_index()

print("Detailed analysis of some duplicated videos:")
print("\nShowing where the same video appears in different locations:")
for _, row in duplicate_analysis.head().iterrows():
    print(f"\nVideo: {row['video_name']}")
    print("Found in:")
    for collector, path in zip(row['collector_name'], row['full_path']):
        print(f"- Collector: {collector}")
        print(f"  Path: {path}")

# Count how many videos appear in which combinations of collectors
collector_combinations = duplicated_videos.groupby('video_name')['collector_name'].apply(lambda x: tuple(sorted(set(x))))
common_patterns = collector_combinations.value_counts()

print("\nCommon patterns of video duplication:")
print(common_patterns.head())
# Out:
# Detailed analysis of some duplicated videos:
#
# Showing where the same video appears in different locations:
#
# Video: 1_2023-06-30_10-58-42-3550_None.MOV
# Found in:
# - Collector: wayne
#   Path: 10_3_2023_all_data/testbed/old_testbed/user_data/wayne/1_2023-06-30_10-58-42-3550_None.MOV
# - Collector: nihal
#   Path: 10_3_2023_all_data/testbed/user_data/nihal/1_2023-06-30_10-58-42-3550_None.MOV
#
# Video: 1_2023-06-30_11-07-11-9360_None.MOV
# Found in:
# - Collector: nihal
#   Path: 10_3_2023_all_data/testbed/user_data/nihal/1_2023-06-30_11-07-11-9360_None.MOV
# - Collector: wayne
#   Path: 10_3_2023_all_data/testbed/old_testbed/user_data/wayne/1_2023-06-30_11-07-11-9360_None.MOV
#
# Video: 1_2023-06-30_11-15-18-5960_None.MOV
# Found in:
# - Collector: nihal
#   Path: 10_3_2023_all_data/testbed/user_data/nihal/1_2023-06-30_11-15-18-5960_None.MOV
# - Collector: wayne
#   Path: 10_3_2023_all_data/testbed/old_testbed/user_data/wayne/1_2023-06-30_11-15-18-5960_None.MOV
#
# Video: 1_2023-06-30_11-23-29-2950_None.MOV
# Found in:
# - Collector: nihal
#   Path: 10_3_2023_all_data/testbed/user_data/nihal/1_2023-06-30_11-23-29-2950_None.MOV
# - Collector: wayne
#   Path: 10_3_2023_all_data/testbed/old_testbed/user_data/wayne/1_2023-06-30_11-23-29-2950_None.MOV
#
# Video: 2_2023-06-30_10-58-42-3550_None.MOV
# Found in:
# - Collector: nihal
#   Path: 10_3_2023_all_data/testbed/user_data/nihal/2_2023-06-30_10-58-42-3550_None.MOV
# - Collector: wayne
#   Path: 10_3_2023_all_data/testbed/old_testbed/user_data/wayne/2_2023-06-30_10-58-42-3550_None.MOV
#
# Common patterns of video duplication:
# collector_name
# (nihal, wayne)    24
# Name: count, dtype: int64

# %%
duplicated_videos
# Out:
#                               video_name collector_name material  \
# 4    1_2023-06-30_10-58-42-3550_None.MOV          wayne     none
# 267  1_2023-06-30_10-58-42-3550_None.MOV          nihal     none
# 266  1_2023-06-30_11-07-11-9360_None.MOV          nihal     none
# 1    1_2023-06-30_11-07-11-9360_None.MOV          wayne     none
# 280  1_2023-06-30_11-15-18-5960_None.MOV          nihal     none
# 34   1_2023-06-30_11-15-18-5960_None.MOV          wayne     none
# 287  1_2023-06-30_11-23-29-2950_None.MOV          nihal     none
# 43   1_2023-06-30_11-23-29-2950_None.MOV          wayne     none
# 272  2_2023-06-30_10-58-42-3550_None.MOV          nihal     none
# 20   2_2023-06-30_10-58-42-3550_None.MOV          wayne     none
# 21   2_2023-06-30_11-07-11-9360_None.MOV          wayne     none
# 273  2_2023-06-30_11-07-11-9360_None.MOV          nihal     none
# 39   2_2023-06-30_11-15-18-5960_None.MOV          wayne     none
# 284  2_2023-06-30_11-15-18-5960_None.MOV          nihal     none
# 277  2_2023-06-30_11-23-29-2950_None.MOV          nihal     none
# 30   2_2023-06-30_11-23-29-2950_None.MOV          wayne     none
# 268  3_2023-06-30_10-58-42-3550_None.MOV          nihal     none
# 8    3_2023-06-30_10-58-42-3550_None.MOV          wayne     none
# 11   3_2023-06-30_11-07-11-9360_None.MOV          wayne     none
# 269  3_2023-06-30_11-07-11-9360_None.MOV          nihal     none
# 276  3_2023-06-30_11-15-18-5960_None.MOV          nihal     none
# 28   3_2023-06-30_11-15-18-5960_None.MOV          wayne     none
# 32   4_2023-06-30_10-58-42-3550_None.MOV          wayne     none
# 278  4_2023-06-30_10-58-42-3550_None.MOV          nihal     none
# 275  4_2023-06-30_11-07-11-9360_None.MOV          nihal     none
# 26   4_2023-06-30_11-07-11-9360_None.MOV          wayne     none
# 270  4_2023-06-30_11-15-18-5960_None.MOV          nihal     none
# 12   4_2023-06-30_11-15-18-5960_None.MOV          wayne     none
# 285  5_2023-06-30_10-58-42-3550_None.MOV          nihal     none
# 41   5_2023-06-30_10-58-42-3550_None.MOV          wayne     none
# 282  5_2023-06-30_11-07-11-9360_None.MOV          nihal     none
# 36   5_2023-06-30_11-07-11-9360_None.MOV          wayne     none
# 274  5_2023-06-30_11-15-18-5960_None.MOV          nihal     none
# 24   5_2023-06-30_11-15-18-5960_None.MOV          wayne     none
# 33   6_2023-06-30_10-58-42-3550_None.MOV          wayne     none
# 279  6_2023-06-30_10-58-42-3550_None.MOV          nihal     none
# 281  6_2023-06-30_11-07-11-9360_None.MOV          nihal     none
# 35   6_2023-06-30_11-07-11-9360_None.MOV          wayne     none
# 265  6_2023-06-30_11-15-18-5960_None.MOV          nihal     none
# 0    6_2023-06-30_11-15-18-5960_None.MOV          wayne     none
# 42   7_2023-06-30_10-58-42-3550_None.MOV          wayne     none
# 286  7_2023-06-30_10-58-42-3550_None.MOV          nihal     none
# 44   7_2023-06-30_11-07-11-9360_None.MOV          wayne     none
# 288  7_2023-06-30_11-07-11-9360_None.MOV          nihal     none
# 271  7_2023-06-30_11-15-18-5960_None.MOV          nihal     none
# 13   7_2023-06-30_11-15-18-5960_None.MOV          wayne     none
# 38   8_2023-06-30_10-58-42-3550_None.MOV          wayne     none
# 283  8_2023-06-30_10-58-42-3550_None.MOV          nihal     none
#
#                                              full_path  duration
# 4    10_3_2023_all_data/testbed/old_testbed/user_da...     59.76
# 267  10_3_2023_all_data/testbed/user_data/nihal/1_2...     59.76
# 266  10_3_2023_all_data/testbed/user_data/nihal/1_2...     59.79
# 1    10_3_2023_all_data/testbed/old_testbed/user_da...     59.79
# 280  10_3_2023_all_data/testbed/user_data/nihal/1_2...     59.79
# 34   10_3_2023_all_data/testbed/old_testbed/user_da...     59.79
# 287  10_3_2023_all_data/testbed/user_data/nihal/1_2...     59.81
# 43   10_3_2023_all_data/testbed/old_testbed/user_da...     59.81
# 272  10_3_2023_all_data/testbed/user_data/nihal/2_2...     59.76
# 20   10_3_2023_all_data/testbed/old_testbed/user_da...     59.76
# 21   10_3_2023_all_data/testbed/old_testbed/user_da...     59.79
# 273  10_3_2023_all_data/testbed/user_data/nihal/2_2...     59.79
# 39   10_3_2023_all_data/testbed/old_testbed/user_da...     59.79
# 284  10_3_2023_all_data/testbed/user_data/nihal/2_2...     59.79
# 277  10_3_2023_all_data/testbed/user_data/nihal/2_2...     26.42
# 30   10_3_2023_all_data/testbed/old_testbed/user_da...     26.42
# 268  10_3_2023_all_data/testbed/user_data/nihal/3_2...     59.82
# 8    10_3_2023_all_data/testbed/old_testbed/user_da...     59.82
# 11   10_3_2023_all_data/testbed/old_testbed/user_da...     59.79
# 269  10_3_2023_all_data/testbed/user_data/nihal/3_2...     59.79
# 276  10_3_2023_all_data/testbed/user_data/nihal/3_2...     59.82
# 28   10_3_2023_all_data/testbed/old_testbed/user_da...     59.82
# 32   10_3_2023_all_data/testbed/old_testbed/user_da...     59.79
# 278  10_3_2023_all_data/testbed/user_data/nihal/4_2...     59.79
# 275  10_3_2023_all_data/testbed/user_data/nihal/4_2...     59.76
# 26   10_3_2023_all_data/testbed/old_testbed/user_da...     59.76
# 270  10_3_2023_all_data/testbed/user_data/nihal/4_2...     59.76
# 12   10_3_2023_all_data/testbed/old_testbed/user_da...     59.76
# 285  10_3_2023_all_data/testbed/user_data/nihal/5_2...     59.79
# 41   10_3_2023_all_data/testbed/old_testbed/user_da...     59.79
# 282  10_3_2023_all_data/testbed/user_data/nihal/5_2...     59.82
# 36   10_3_2023_all_data/testbed/old_testbed/user_da...     59.82
# 274  10_3_2023_all_data/testbed/user_data/nihal/5_2...     59.80
# 24   10_3_2023_all_data/testbed/old_testbed/user_da...     59.80
# 33   10_3_2023_all_data/testbed/old_testbed/user_da...     59.79
# 279  10_3_2023_all_data/testbed/user_data/nihal/6_2...     59.79
# 281  10_3_2023_all_data/testbed/user_data/nihal/6_2...     59.79
# 35   10_3_2023_all_data/testbed/old_testbed/user_da...     59.79
# 265  10_3_2023_all_data/testbed/user_data/nihal/6_2...     59.79
# 0    10_3_2023_all_data/testbed/old_testbed/user_da...     59.79
# 42   10_3_2023_all_data/testbed/old_testbed/user_da...     59.82
# 286  10_3_2023_all_data/testbed/user_data/nihal/7_2...     59.82
# 44   10_3_2023_all_data/testbed/old_testbed/user_da...     53.93
# 288  10_3_2023_all_data/testbed/user_data/nihal/7_2...     53.93
# 271  10_3_2023_all_data/testbed/user_data/nihal/7_2...     59.19
# 13   10_3_2023_all_data/testbed/old_testbed/user_da...     59.19
# 38   10_3_2023_all_data/testbed/old_testbed/user_da...      0.73
# 283  10_3_2023_all_data/testbed/user_data/nihal/8_2...      0.73

# %%
import pandas as pd

# 1. 处理 static_videos.csv
static_csv = 'data/static_videos.csv'
static_df = pd.read_csv(static_csv)
static_prefix = 'https://storage.googleapis.com/labelbox-sidewalk-legacy-data-static/'

def mov_to_mp4(name):
    if name.lower().endswith('.mov'):
        return name[:-4] + '.mp4'
    return name

static_df['download_link'] = static_prefix + static_df['video_name'].apply(mov_to_mp4)
static_df.to_csv(static_csv, index=False)
print(f"static_videos_with_link.csv saved, shape: {static_df.shape}")

# 2. 处理 continuous_videos_clean.csv
cont_csv = 'data/continuous_videos_clean.csv'
cont_df = pd.read_csv(cont_csv)
cont_prefix = 'https://storage.googleapis.com/labelbox-sidewalk-legacy-data-continuous/'

cont_df['download_link'] = cont_prefix + cont_df['video_name'].apply(mov_to_mp4)
cont_df.to_csv(cont_csv, index=False)
print(f"continuous_videos_clean_with_link.csv saved, shape: {cont_df.shape}")
# Out:
# static_videos_with_link.csv saved, shape: (770, 6)
# continuous_videos_clean_with_link.csv saved, shape: (731, 6)

# %%
static_df.head()
# Out:
#                                     video_name  collector_name      material  \
# 0  0_2023-08-21 13_31_45.3030_Subway+grate.MOV  jiawei_testbed  subway_grate
# 1       0_2023-08-21 13_25_10.3210_Manhole.MOV  jiawei_testbed       manhole
# 2  1_2023-08-21 13_31_45.3030_Subway+grate.MOV  jiawei_testbed  subway_grate
# 3   0_2023-08-21 13_35_23.4820_Cellar+door.MOV  jiawei_testbed   cellar_door
# 4       0_2023-08-21 13_24_23.9400_Manhole.MOV  jiawei_testbed       manhole
#
#                                            full_path  duration  \
# 0  10_3_2023_all_data/testbed/user_data/jiawei_te...     59.85
# 1  10_3_2023_all_data/testbed/user_data/jiawei_te...      5.60
# 2  10_3_2023_all_data/testbed/user_data/jiawei_te...      3.20
# 3  10_3_2023_all_data/testbed/user_data/jiawei_te...      9.37
# 4  10_3_2023_all_data/testbed/user_data/jiawei_te...      7.40
#
#                                        download_link
# 0  https://storage.googleapis.com/labelbox-sidewa...
# 1  https://storage.googleapis.com/labelbox-sidewa...
# 2  https://storage.googleapis.com/labelbox-sidewa...
# 3  https://storage.googleapis.com/labelbox-sidewa...
# 4  https://storage.googleapis.com/labelbox-sidewa...
